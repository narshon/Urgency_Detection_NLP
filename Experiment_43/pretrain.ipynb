# %%
from sklearn.metrics import (
    plot_precision_recall_curve, precision_recall_curve, 
    confusion_matrix)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
! pip install torch datasets transformers==4.11.3
#conda install -c huggingface -c conda-forge datasets
#conda install -c huggingface -c conda-forge transformers==4.11.3

# %%
#export CUDA_DEVICE_ORDER='PCI_BUS_ID'
#export CUDA_VISIBLE_DEVICES='0'
#CUDA_VISIBLE_DEVICES=0

python run_mlm.py \
    --model_name_or_path "castorini/afriberta_large" \
    --train_file input/nurse_train_df_v7.csv \
    --validation_file input/nurse_dev_df_v7.csv \
    --do_train \
    --do_eval \
    --save_total_limit 1 \
    --mlm_probability 0.15 \
    --num_train_epochs 5 \
    --max_seq_length 512 \
    --overwrite_output_dir \
    --report_to all \
    --per_device_train_batch_size 4 \
    --per_device_eval_batch_size 4 \
    --gradient_accumulation_steps 2 \
    --output_dir model

# %%
#System finetuned only -- using mBERT model
#%cd drive/MyDrive/Pipeline_v3_2/datasets/input/system/

#request resources
salloc -A ark -p gpu-2080ti -N 1 -c 10 --mem=100G --time=10:00:00 --gpus-per-node=1

#Activate python env
conda activate pytorch-cuda11

#change transformers cache
export TRANSFORMERS_CACHE=/gscratch/scrubbed/nngao/transformer_cache
#https://huggingface.co/docs/datasets/v1.12.0/cache.html
#dataset cache
export HF_DATASETS_CACHE="/gscratch/scrubbed/nngao/cache"

#Cuda devices
export CUDA_DEVICE_ORDER="PCI_BUS_ID"
export CUDA_VISIBLE_DEVICES="0"
# Out:
# /content/drive/MyDrive/Pipeline_v3_2/datasets/input/system
