# %%
from sklearn.metrics import (
    plot_precision_recall_curve, precision_recall_curve, confusion_matrix, classification_report)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Results Analyis
results_df = pd.read_csv("output/exp46_results.csv")
results_df
# Out:
#       Unnamed: 0   Label_0   Label_1   Label_2  y_predicted  label     mid  \
# 0              0  0.253515  0.292684  0.453801            2      2  212992
# 1              1  0.085808  0.179886  0.734306            2      2  196784
# 2              2  0.253903  0.292596  0.453502            2      2  194959
# 3              3  0.253933  0.292588  0.453479            2      1  183920
# 4              4  0.253573  0.292671  0.453757            2      0  202729
# ...          ...       ...       ...       ...          ...    ...     ...
# 2332        2332  0.253809  0.292617  0.453574            2      0  193167
# 2333        2333  0.084740  0.177207  0.738053            2      2  167597
# 2334        2334  0.086230  0.180174  0.733596            2      2  192833
# 2335        2335  0.082059  0.171090  0.746850            2      2  193644
# 2336        2336  0.083262  0.174210  0.742528            2      2  197369
#
#        pid      sent_by           lang  \
# 0     4122  participant        swahili
# 1     3615  participant  Code-Switched
# 2     3559  participant        english
# 3     3278  participant        english
# 4     3746  participant        swahili
# ...    ...          ...            ...
# 2332  3524  participant        swahili
# 2333  2943  participant        swahili
# 2334  3514  participant        english
# 2335  3534  participant        english
# 2336  3628  participant          sheng
#
#                                                    text
# 0     Amna wasiwasi wowote Watoto wachanga wanafaa k...
# 1                                              Recevid
# 2     No Newborns need to be kept warm. The baby is ...
# 3     At first he has rashes on his face but they go...
# 4     Hapana sijafura mikono ama miguu but kuna ile ...
# ...                                                 ...
# 2332  Nikona joto  haswa wakati WA usiku iwapo inaku...
# 2333  Niko poa Winnie,Ni kuwa_miss tu aki. Poa sana....
# 2334  Okay, Thankyou. good morning jacinter, that's ...
# 2335           same Wow That is great. Have a nice day.
# 2336   hakuna  sms yoyote nimepata Asante kwa kujiun...
#
# [2337 rows x 11 columns]

# %%
pd.crosstab(results_df.label, results_df.y_predicted)
# Out:
# y_predicted     2
# label
# 0             500
# 1             641
# 2            1196

# %%
from sklearn.metrics import classification_report
print(classification_report(results_df.label, results_df.y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       500
#            1       0.00      0.00      0.00       641
#            2       0.51      1.00      0.68      1196
#
#     accuracy                           0.51      2337
#    macro avg       0.17      0.33      0.23      2337
# weighted avg       0.26      0.51      0.35      2337
# C:\Users\nngao\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\nngao\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\nngao\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
