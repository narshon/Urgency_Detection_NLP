# %%
from sklearn.metrics import (
    plot_precision_recall_curve, precision_recall_curve, confusion_matrix, classification_report)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Results Analyis
results_df = pd.read_csv("output/exp42_results.csv")
results_df
# Out:
#       Unnamed: 0   Label_0   Label_1   Label_2   Label_3   Label_4  \
# 0              0  0.047349  0.185372  0.323768  0.154179  0.289331
# 1              1  0.047357  0.185390  0.323813  0.154176  0.289264
# 2              2  0.012036  0.043454  0.073174  0.049427  0.821910
# 3              3  0.047230  0.185203  0.323434  0.154082  0.290052
# 4              4  0.011762  0.042918  0.072890  0.048053  0.824377
# ...          ...       ...       ...       ...       ...       ...
# 2332        2332  0.047390  0.185400  0.323829  0.154221  0.289159
# 2333        2333  0.049399  0.182879  0.316846  0.158351  0.292525
# 2334        2334  0.047411  0.185443  0.323963  0.154229  0.288954
# 2335        2335  0.012049  0.043514  0.073267  0.049484  0.821686
# 2336        2336  0.047457  0.185492  0.324169  0.154292  0.288590
#
#       y_predicted  label     mid   pid      sent_by     lang  \
# 0               2      2  202626  3745  participant  english
# 1               2      3  199398  3673  participant  swahili
# 2               4      2  200672  3701  participant  english
# 3               2      3  189864  3424  participant  english
# 4               4      4  209192  3993  participant  english
# ...           ...    ...     ...   ...          ...      ...
# 2332            2      0  204535  3795  participant  english
# 2333            2      2  180561  3208  participant  swahili
# 2334            2      4   38237   349  participant  swahili
# 2335            4      4  157814  2728  participant  english
# 2336            2      2  157916  2730  participant      luo
#
#                                                    text
# 0     Meaning of latching please Ensure you baby is ...
# 1     Kuosha Mara tu mtoto anapozaliwa unaweza zuia ...
# 2     Thank you what about the second question? Hell...
# 3     Rachuonyo sub county hospital unless otherwise...
# 4     Okay thank you for your concern please Hello S...
# ...                                                 ...
# 2332  No Regular, strong abdominal pains are a sign ...
# 2333  Hakuna kuweka spirit. Unahitaji kitambaa safi ...
# 2334  nisawa Tarehe unarudi clinic pale ulikuja siku...
# 2335  Thank you We really appreciate your messages a...
# 2336  Podi thuno ema odhodho Be isechako miye chiemo...
#
# [2337 rows x 13 columns]

# %%
pd.crosstab(results_df.label, results_df.y_predicted)
# Out:
# y_predicted    2    4
# label
# 0            100    2
# 1            370   28
# 2            590   51
# 3            282   49
# 4            512  353

# %%
from sklearn.metrics import classification_report
print(classification_report(results_df.label, results_df.y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       102
#            1       0.00      0.00      0.00       398
#            2       0.32      0.92      0.47       641
#            3       0.00      0.00      0.00       331
#            4       0.73      0.41      0.52       865
#
#     accuracy                           0.40      2337
#    macro avg       0.21      0.27      0.20      2337
# weighted avg       0.36      0.40      0.32      2337
# C:\Users\nngao\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\nngao\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\nngao\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
