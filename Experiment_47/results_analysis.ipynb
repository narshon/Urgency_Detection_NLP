# %%
from sklearn.metrics import (
    plot_precision_recall_curve, precision_recall_curve, confusion_matrix, classification_report)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Results Analyis
results_df = pd.read_csv("output/exp41_results.csv")
results_df
# Out:
#       Unnamed: 0   Label_0   Label_1   Label_2   Label_3   Label_4  \
# 0              0  0.040892  0.160963  0.282980  0.137419  0.377747
# 1              1  0.040890  0.160955  0.282977  0.137419  0.377759
# 2              2  0.040892  0.160963  0.282980  0.137418  0.377747
# 3              3  0.040891  0.160963  0.282980  0.137418  0.377748
# 4              4  0.040892  0.160963  0.282980  0.137418  0.377748
# ...          ...       ...       ...       ...       ...       ...
# 2332        2332  0.040892  0.160963  0.282980  0.137419  0.377747
# 2333        2333  0.040889  0.160955  0.282976  0.137420  0.377760
# 2334        2334  0.040890  0.160956  0.282977  0.137420  0.377758
# 2335        2335  0.040892  0.160963  0.282980  0.137418  0.377747
# 2336        2336  0.040889  0.160953  0.282974  0.137421  0.377764
#
#       y_predicted  label     mid   pid      sent_by     lang  \
# 0               4      2  202626  3745  participant  english
# 1               4      3  199398  3673  participant  swahili
# 2               4      2  200672  3701  participant  english
# 3               4      3  189864  3424  participant  english
# 4               4      4  209192  3993  participant  english
# ...           ...    ...     ...   ...          ...      ...
# 2332            4      0  204535  3795  participant  english
# 2333            4      2  180561  3208  participant  swahili
# 2334            4      4   38237   349  participant  swahili
# 2335            4      4  157814  2728  participant  english
# 2336            4      2  157916  2730  participant      luo
#
#                                                    text
# 0     Meaning of latching please Newborn skin often ...
# 1     Kuosha Mara tu mtoto anapozaliwa unaweza zuia ...
# 2     Thank you what about the second question? Than...
# 3     Rachuonyo sub county hospital unless otherwise...
# 4     Okay thank you for your concern please Severe ...
# ...                                                 ...
# 2332  No Regular, strong abdominal pains are a sign ...
# 2333  Hakuna kuweka spirit. Watoto wachanga wanafaa ...
# 2334  nisawa  Wiki hii SMS zitaacha Tafadhali kuja u...
# 2335  Thank you We really appreciate your messages a...
# 2336  Podi thuno ema odhodho E thuolo mar juma achie...
#
# [2337 rows x 13 columns]

# %%
pd.crosstab(results_df.label, results_df.y_predicted)
# Out:
# y_predicted    4
# label
# 0            102
# 1            398
# 2            641
# 3            331
# 4            865

# %%
from sklearn.metrics import classification_report
print(classification_report(results_df.label, results_df.y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       102
#            1       0.00      0.00      0.00       398
#            2       0.00      0.00      0.00       641
#            3       0.00      0.00      0.00       331
#            4       0.37      1.00      0.54       865
#
#     accuracy                           0.37      2337
#    macro avg       0.07      0.20      0.11      2337
# weighted avg       0.14      0.37      0.20      2337
# C:\Users\nngao\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\nngao\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\nngao\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
