# %%
from sklearn.metrics import (
    plot_precision_recall_curve, precision_recall_curve, confusion_matrix, classification_report)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
results_df = pd.read_csv("Reports/languages/language_analysis_results.csv")
#filter for +ve label only
results_df = results_df[results_df.label == '1']
results_df
# Out:
#      Unnamed: 0  index label  precision    recall  f1-score  support language  \
# 1             1      1     1   0.449275  0.389121  0.417040      239  english
# 6             6      6     1   0.492308  0.304762  0.376471      210  swahili
# 11           11     11     1   0.666667  0.111111  0.190476       18      luo
# 16           16     16     1   0.538462  0.333333  0.411765       21    sheng
# 21           21      1     1   0.530769  0.288703  0.373984      239  english
# 26           26      6     1   0.460177  0.247619  0.321981      210  swahili
# 31           31     11     1   0.000000  0.000000  0.000000       18      luo
# 36           36     16     1   0.533333  0.380952  0.444444       21    sheng
# 41           41      1     1   0.546448  0.418410  0.473934      239  english
# 46           46      6     1   0.521127  0.352381  0.420455      210  swahili
# 51           51     11     1   0.500000  0.277778  0.357143       18      luo
# ...

# %%
# showing results for English with pretrained models
#results_df.drop(['index','Unnamed: 0'], axis = 1, inplace=True)
english_df = results_df[(results_df.Experiment.isin(["Exp26","Exp34","Exp27","Exp35"])) & (results_df.language == "english") ]
english_df['model'] = ["mBERT","mBERT","AfriBERTa","AfriBERTa"]
english_df['context'] = ["system","nurse","system","nurse"]
english_df.to_csv("Reports/languages/english_results.csv")
# Out:
# C:\Users\nngao\AppData\Local\Temp\ipykernel_15280\883939063.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_df['model'] = ["mBERT","mBERT","AfriBERTa","AfriBERTa"]
# C:\Users\nngao\AppData\Local\Temp\ipykernel_15280\883939063.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_df['context'] = ["system","nurse","system","nurse"]

# %%
# showing results for English with pretrained models
english_df = results_df[(results_df.Experiment.isin(["Exp26","Exp34","Exp27","Exp35"])) & (results_df.language == "swahili") ]
english_df['model'] = ["mBERT","mBERT","AfriBERTa","AfriBERTa"]
english_df['context'] = ["system","nurse","system","nurse"]
english_df.to_csv("Reports/languages/swahili_results.csv")
# Out:
# C:\Users\nngao\AppData\Local\Temp\ipykernel_15280\2305854194.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_df['model'] = ["mBERT","mBERT","AfriBERTa","AfriBERTa"]
# C:\Users\nngao\AppData\Local\Temp\ipykernel_15280\2305854194.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_df['context'] = ["system","nurse","system","nurse"]

# %%
# showing results for English with pretrained models
#results_df.drop(['index','Unnamed: 0'], axis = 1, inplace=True)
english_df = results_df[(results_df.Experiment.isin(["Exp26","Exp34","Exp27","Exp35"])) & (results_df.language == "luo") ]
english_df['model'] = ["mBERT","mBERT","AfriBERTa","AfriBERTa"]
english_df['context'] = ["system","nurse","system","nurse"]
english_df.to_csv("Reports/languages/luo_results.csv")
# Out:
# C:\Users\nngao\AppData\Local\Temp\ipykernel_15280\4008491949.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_df['model'] = ["mBERT","mBERT","AfriBERTa","AfriBERTa"]
# C:\Users\nngao\AppData\Local\Temp\ipykernel_15280\4008491949.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_df['context'] = ["system","nurse","system","nurse"]

# %%
# showing results for English with pretrained models
#results_df.drop(['index','Unnamed: 0'], axis = 1, inplace=True)
english_df = results_df[(results_df.Experiment.isin(["Exp26","Exp34","Exp27","Exp35"])) & (results_df.language == "sheng") ]
english_df['model'] = ["mBERT","mBERT","AfriBERTa","AfriBERTa"]
english_df['context'] = ["system","nurse","system","nurse"]
english_df.to_csv("Reports/languages/sheng_results.csv")
# Out:
# C:\Users\nngao\AppData\Local\Temp\ipykernel_15280\383859638.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_df['model'] = ["mBERT","mBERT","AfriBERTa","AfriBERTa"]
# C:\Users\nngao\AppData\Local\Temp\ipykernel_15280\383859638.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_df['context'] = ["system","nurse","system","nurse"]
